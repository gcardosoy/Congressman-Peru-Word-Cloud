# %%
import pandas as pd

# %%
congresistas = pd.read_excel("congresistasCuentasTwitter.xlsx", sheet_name="congresistas")
columns = ["name","twitter_user", "twitter_username","auxiliar_query"]
congresistasDF = congresistas[columns]

# %%
congresistas["partido"].value_counts()
# Out:
# Fuerza Popular                                 54
# Nuevo Perú                                     10
# Alianza para el Progreso                       10
# Frente Amplio por Justicia, Vida y Libertad     9
# Cambio 21                                       7
# Contigo                                         6
# Acción Popular                                  6
# Célula Parlamentaria Aprista                    5
# Unidos por la República                         5
# Bancada Liberal                                 5
# Peruanos por el Kambio                          5
# Acción Repúblicana                              5
# No Agrupados                                    3
# Name: partido, dtype: int64

# %%
congresistas = pd.read_excel("congresistasCuentasTwitter.xlsx", sheet_name="congresistas")
congresistas.loc[congresistas["partido_id"] == "P01"]
# Out:
#   partido_id                                       partido_logo  \
# 0        P01  https://votoinformado.jne.gob.pe/voto/Resource...
# 1        P01  https://votoinformado.jne.gob.pe/voto/Resource...
# 2        P01  https://votoinformado.jne.gob.pe/voto/Resource...
# 3        P01  https://votoinformado.jne.gob.pe/voto/Resource...
# 4        P01  https://votoinformado.jne.gob.pe/voto/Resource...
# 5        P01  https://votoinformado.jne.gob.pe/voto/Resource...
#
#           partido                 nombre_completo           apellidos  \
# 0  Acción Popular     Del Águila Herrera, Edmundo  Del Águila Herrera
# 1  Acción Popular  García Belaunde, Víctor Andrés     García Belaunde
# 2  Acción Popular          Lescano Ancieta, Yonhy     Lescano Ancieta
# 3  Acción Popular      Noceda Chiang, Paloma Rosa       Noceda Chiang
# 4  Acción Popular          Román Valdivia, Miguel      Román Valdivia
# 5  Acción Popular     Villanueva Mercado, Armando  Villanueva Mercado
#
# ...

# %%
pd.read_excel("congresistasCuentasTwitter.xlsx", sheet_name="partidos")
# Out:
#    partido_id                                       partido_logo  \
# 0         P01  https://votoinformado.jne.gob.pe/voto/Resource...
# 1         P02  https://www.google.com/url?sa=i&source=images&...
# 2         P03  https://votoinformado.jne.gob.pe/voto/Resource...
# 3         P04  https://www.google.com/url?sa=i&source=images&...
# 4         P05  https://www.google.com/url?sa=i&source=images&...
# 5         P06  https://votoinformado.jne.gob.pe/voto/Resource...
# 6         P07  https://votoinformado.jne.gob.pe/voto/Resource...
# 7         P08  https://votoinformado.jne.gob.pe/voto/Resource...
# 8         P09  https://votoinformado.jne.gob.pe/voto/Resource...
# 9         P10  https://www.google.com/url?sa=i&source=images&...
# 10        P11  https://www.google.com/url?sa=i&source=images&...
# 11        P12  https://www.google.com/url?sa=i&source=images&...
# 12        P13  https://votoinformado.jne.gob.pe/voto/Resource...
#
#                                         partido
# ...

# %%
congresistas["partido"].unique()
# Out:
# array(['Acción Popular', 'Acción Repúblicana', 'Alianza para el Progreso',
#        'Bancada Liberal', 'Cambio 21', 'Célula Parlamentaria Aprista',
#        'Contigo', 'Frente Amplio por Justicia, Vida y Libertad',
#        'Fuerza Popular', 'No Agrupados', 'Nuevo Perú',
#        'Peruanos por el Kambio', 'Unidos por la República'], dtype=object)

# %%
[x for x in congresistas["partido_logo"].unique()]
# Out:
# ['https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/4.JPG',
#  'https://www.google.com/url?sa=i&source=images&cd=&ved=2ahUKEwjFxZae9Z_mAhUBwVkKHTt6DFMQjRx6BAgBEAQ&url=https%3A%2F%2Fes.wikipedia.org%2Fwiki%2FAcci%25C3%25B3n_Republicana_(bancada)&psig=AOvVaw1HlWDJdDX40nGPSMRZD3Xl&ust=1575683658270004',
#  'https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/1257.JPG',
#  'https://www.google.com/url?sa=i&source=images&cd=&ved=2ahUKEwjC8frH9Z_mAhUl01kKHRTQAIUQjRx6BAgBEAQ&url=https%3A%2F%2Fes.wikipedia.org%2Fwiki%2FBancada_Liberal&psig=AOvVaw1diQc8rO76c73ND7c4PpVy&ust=1575683754486794',
#  'https://www.google.com/url?sa=i&source=images&cd=&ved=2ahUKEwjrrL3t9Z_mAhWDtVkKHa8ZDYAQjRx6BAgBEAQ&url=https%3A%2F%2Ftwitter.com%2Fcambio21bancada&psig=AOvVaw0N-vIPb3RMa8PDwGXeW5yi&ust=1575683830361903',
#  'https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/32.JPG',
#  'https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/2235.JPG',
# ...

# %%
congresistas.loc[congresistas["partido"] == "Célula Parlamentaria Aprista"]["partido_logo"].values
# Out:
# array(['https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/32.JPG',
#        'https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/32.JPG',
#        'https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/32.JPG',
#        'https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/32.JPG',
#        'https://votoinformado.jne.gob.pe/voto/Resources/imgs/logoop/32.JPG'],
#       dtype=object)
